# %% [markdown]
# **1. Importing the Python tools and libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %% [markdown]
# **2. Importing the dataset file in the code and analysing the data**

# %%
data= pd.read_csv("/fraudTest[1].csv")

# %%
data.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %%
data.tail()
# Out:
#        Unnamed: 0 trans_date_trans_time            cc_num  \
# 58338       58338   2020-07-11 20:09:44  2720433095629877
# 58339       58339   2020-07-11 20:10:06  3525668150756629
# 58340       58340   2020-07-11 20:11:30  6011492816282597
# 58341       58341   2020-07-11 20:11:43  3590736522064285
# 58342       58342   2020-07-11 20:12:20     4500002361389
#
#                      merchant       category     amt        first      last  \
# 58338     fraud_Wilkinson PLC      kids_pets   18.96         Mark      Wood
# 58339   fraud_Kirlin and Sons  personal_care   85.58  Christopher      Choi
# 58340          fraud_Howe PLC  entertainment   58.64         Gary    Barnes
# 58341  fraud_Nolan-Williamson      kids_pets  104.11     Kimberly  Gonzalez
# 58342        fraud_Schoen Ltd      kids_pets  110.69       Joseph     Nixon
#
#       gender                         street  ...      lat     long  city_pop  \
# 58338      M      854 Walker Dale Suite 488  ...  44.0575 -69.9656      3224
# ...

# %%
data.shape
# Out:
# (58343, 23)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58343 entries, 0 to 58342
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             58343 non-null  int64
#  1   trans_date_trans_time  58343 non-null  object
#  2   cc_num                 58343 non-null  int64
#  3   merchant               58343 non-null  object
#  4   category               58343 non-null  object
#  5   amt                    58343 non-null  float64
#  6   first                  58343 non-null  object
#  7   last                   58343 non-null  object
#  8   gender                 58343 non-null  object
#  9   street                 58343 non-null  object
#  10  city                   58343 non-null  object
#  11  state                  58343 non-null  object
#  12  zip                    58343 non-null  int64
#  13  lat                    58343 non-null  float64
# ...

# %%
data.dtypes
# Out:
# Unnamed: 0                 int64
# trans_date_trans_time     object
# cc_num                     int64
# merchant                  object
# category                  object
# amt                      float64
# first                     object
# last                      object
# gender                    object
# street                    object
# city                      object
# state                     object
# zip                        int64
# lat                      float64
# long                     float64
# city_pop                   int64
# job                       object
# dob                       object
# trans_num                 object
# unix_time                float64
# merch_lat                float64
# merch_long               float64
# is_fraud                 float64
# dtype: object

# %%
data.dtypes.value_counts().plot(kind='bar', color="black");

# %%
data.describe().T
# Out:
#               count          mean           std           min           25%  \
# Unnamed: 0  58343.0  2.917100e+04  1.684232e+04  0.000000e+00  1.458550e+04
# cc_num      58343.0  4.145401e+17  1.305182e+18  6.041621e+10  1.800365e+14
# amt         58343.0  6.926694e+01  1.464025e+02  1.000000e+00  9.700000e+00
# zip         58343.0  4.871677e+04  2.682087e+04  1.257000e+03  2.623700e+04
# lat         58343.0  3.854323e+01  5.080845e+00  2.002710e+01  3.466890e+01
# long        58343.0 -9.014895e+01  1.366482e+01 -1.656723e+02 -9.678690e+01
# city_pop    58343.0  9.022664e+04  3.044689e+05  2.300000e+01  7.430000e+02
# unix_time   58342.0  1.372663e+09  5.092432e+05  1.371817e+09  1.372235e+09
# merch_lat   58342.0  3.854100e+01  5.115351e+00  1.904232e+01  3.474815e+01
# merch_long  58342.0 -9.014782e+01  1.367774e+01 -1.666463e+02 -9.683673e+01
# is_fraud    58342.0  4.010833e-03  6.320454e-02  0.000000e+00  0.000000e+00
#
#                      50%           75%           max
# ...

# %%
data.is_fraud.value_counts()
# Out:
# is_fraud
# 0.0    58108
# 1.0      234
# Name: count, dtype: int64

# %%
plt.pie(data.is_fraud.value_counts(), labels=["Normal values", "Fraud values"])
plt.show()

# %% [markdown]
# **3. Data Preprocessing**

# %%
data.drop_duplicates()
# Out:
#        Unnamed: 0 trans_date_trans_time            cc_num  \
# 0               0   2020-06-21 12:14:25  2291163933867244
# 1               1   2020-06-21 12:14:33  3573030041201292
# 2               2   2020-06-21 12:14:53  3598215285024754
# 3               3   2020-06-21 12:15:15  3591919803438423
# 4               4   2020-06-21 12:15:17  3526826139003047
# ...           ...                   ...               ...
# 58338       58338   2020-07-11 20:09:44  2720433095629877
# 58339       58339   2020-07-11 20:10:06  3525668150756629
# 58340       58340   2020-07-11 20:11:30  6011492816282597
# 58341       58341   2020-07-11 20:11:43  3590736522064285
# 58342       58342   2020-07-11 20:12:20     4500002361389
#
#                                    merchant        category     amt  \
# 0                     fraud_Kirlin and Sons   personal_care    2.86
# 1                      fraud_Sporer-Keebler   personal_care   29.84
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.dropna()
# Out:
#        Unnamed: 0 trans_date_trans_time            cc_num  \
# 0               0   2020-06-21 12:14:25  2291163933867244
# 1               1   2020-06-21 12:14:33  3573030041201292
# 2               2   2020-06-21 12:14:53  3598215285024754
# 3               3   2020-06-21 12:15:15  3591919803438423
# 4               4   2020-06-21 12:15:17  3526826139003047
# ...           ...                   ...               ...
# 58337       58337   2020-07-11 20:08:11      581293083266
# 58338       58338   2020-07-11 20:09:44  2720433095629877
# 58339       58339   2020-07-11 20:10:06  3525668150756629
# 58340       58340   2020-07-11 20:11:30  6011492816282597
# 58341       58341   2020-07-11 20:11:43  3590736522064285
#
#                                    merchant        category     amt  \
# 0                     fraud_Kirlin and Sons   personal_care    2.86
# 1                      fraud_Sporer-Keebler   personal_care   29.84
# ...

# %%
data.isnull()
# Out:
#        Unnamed: 0  trans_date_trans_time  cc_num  merchant  category    amt  \
# 0           False                  False   False     False     False  False
# 1           False                  False   False     False     False  False
# 2           False                  False   False     False     False  False
# 3           False                  False   False     False     False  False
# 4           False                  False   False     False     False  False
# ...           ...                    ...     ...       ...       ...    ...
# 58338       False                  False   False     False     False  False
# 58339       False                  False   False     False     False  False
# 58340       False                  False   False     False     False  False
# 58341       False                  False   False     False     False  False
# 58342       False                  False   False     False     False  False
#
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                1
# merch_lat                1
# merch_long               1
# is_fraud                 1
# dtype: int64

# %%
data.nunique()
# Out:
# Unnamed: 0               58343
# trans_date_trans_time    57243
# cc_num                     911
# merchant                   693
# category                    14
# amt                      17095
# first                      339
# last                       467
# gender                       2
# street                     911
# city                       839
# state                       50
# zip                        900
# lat                        898
# long                       898
# city_pop                   825
# job                        476
# dob                        897
# trans_num                58343
# unix_time                57242
# merch_lat                58236
# merch_long               58286
# is_fraud                     2
# dtype: int64

# %%
data= data.drop(columns=['Unnamed: 0','first','last','state','city_pop','job','dob'])

# %%
data.head()
# Out:
#   trans_date_trans_time            cc_num  \
# 0   2020-06-21 12:14:25  2291163933867244
# 1   2020-06-21 12:14:33  3573030041201292
# 2   2020-06-21 12:14:53  3598215285024754
# 3   2020-06-21 12:15:15  3591919803438423
# 4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt gender  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86      M
# 1                  fraud_Sporer-Keebler   personal_care  29.84      F
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28      F
# 3                     fraud_Haley Group        misc_pos  60.05      M
# 4                 fraud_Johnston-Casper          travel   3.19      M
#
#                         street        city    zip      lat      long  \
# 0            351 Darlene Green    Columbia  29209  33.9659  -80.9355
# 1             3638 Marsh Union     Altonah  84002  40.3207 -110.4360
# 2         9333 Valentine Point    Bellmore  11710  40.6729  -73.5365
# ...

# %%
data.nunique()
# Out:
# trans_date_trans_time    57243
# cc_num                     911
# merchant                   693
# category                    14
# amt                      17095
# gender                       2
# street                     911
# city                       839
# zip                        900
# lat                        898
# long                       898
# trans_num                58343
# unix_time                57242
# merch_lat                58236
# merch_long               58286
# is_fraud                     2
# dtype: int64

# %% [markdown]
# **4. Feature Extraction and Data Transformation**

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()
data['merchant']=encoder.fit_transform(data['merchant'])
data['category']=encoder.fit_transform(data['category'])
data['street']=encoder.fit_transform(data['street'])
data['trans_num']=encoder.fit_transform(data['trans_num'])
data['city']=encoder.fit_transform(data['city'])
data['gender']=encoder.fit_transform(data['gender'])
data['trans_date_trans_time']=encoder.fit_transform(data['trans_date_trans_time'])

# %%
data.head()
# Out:
#    trans_date_trans_time            cc_num  merchant  category    amt  gender  \
# 0                      0  2291163933867244       319        10   2.86       1
# 1                      1  3573030041201292       591        10  29.84       0
# 2                      2  3598215285024754       611         5  41.28       0
# 3                      3  3591919803438423       222         9  60.05       1
# 4                      4  3526826139003047       292        13   3.19       1
#
#    street  city    zip      lat      long  trans_num     unix_time  merch_lat  \
# 0     338   157  29209  33.9659  -80.9355      10287  1.371817e+09  33.986391
# 1     351    16  84002  40.3207 -110.4360      11359  1.371817e+09  39.450498
# 2     853    61  11710  40.6729  -73.5365      45570  1.371817e+09  40.495810
# 3     317   755  32780  28.5697  -80.8191       7520  1.371817e+09  28.812398
# 4     542   246  49632  44.2529  -85.0170      19887  1.371817e+09  44.959148
#
#    merch_long  is_fraud
# ...

# %% [markdown]
# **5. Data Training and Processing - Without Sampling**

# %%
from sklearn.model_selection import train_test_split

# %%
train_data, test_data = train_test_split(data, test_size=0.3)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40840 entries, 21217 to 57257
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   trans_date_trans_time  40840 non-null  int64
#  1   cc_num                 40840 non-null  int64
#  2   merchant               40840 non-null  int64
#  3   category               40840 non-null  int64
#  4   amt                    40840 non-null  float64
#  5   gender                 40840 non-null  int64
#  6   street                 40840 non-null  int64
#  7   city                   40840 non-null  int64
#  8   zip                    40840 non-null  int64
#  9   lat                    40840 non-null  float64
#  10  long                   40840 non-null  float64
#  11  trans_num              40840 non-null  int64
#  12  unix_time              40840 non-null  float64
#  13  merch_lat              40840 non-null  float64
# ...

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17503 entries, 7789 to 40679
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   trans_date_trans_time  17503 non-null  int64
#  1   cc_num                 17503 non-null  int64
#  2   merchant               17503 non-null  int64
#  3   category               17503 non-null  int64
#  4   amt                    17503 non-null  float64
#  5   gender                 17503 non-null  int64
#  6   street                 17503 non-null  int64
#  7   city                   17503 non-null  int64
#  8   zip                    17503 non-null  int64
#  9   lat                    17503 non-null  float64
#  10  long                   17503 non-null  float64
#  11  trans_num              17503 non-null  int64
#  12  unix_time              17502 non-null  float64
#  13  merch_lat              17502 non-null  float64
# ...

# %%
x_train=train_data.drop(columns=['is_fraud'])
y_train=train_data['is_fraud']
x_test=test_data.drop(columns=['is_fraud'])
y_test=test_data['is_fraud']

# %%
nan_indices = y_test[y_test.isnull()].index

# Remove these rows from both x_test and y_test
x_test = x_test.drop(index=nan_indices)
y_test = y_test.drop(index=nan_indices)

# %%
x_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((40840, 15), (40840,), (17503, 15), (17502,))

# %% [markdown]
# **Data Modelling - Without Sampling**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RF=RandomForestClassifier(random_state=42)

# %%
RF.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
pred_RF = RF.predict(x_test)

# %% [markdown]
# **Evaluation Metrics - Without Ssampling**

# %%
import sklearn.metrics as metrics
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, classification_report

# %%
accRF = accuracy_score(y_test, pred_RF)
accRF
# Out:
# 0.9979430922180322

# %%
precRF = precision_score(y_test, pred_RF)
precRF
# Out:
# 1.0

# %%
recall_RF = recall_score(y_test, pred_RF)
recall_RF
# Out:
# 0.5324675324675324

# %%
F1_RF = f1_score(y_test, pred_RF)
F1_RF
# Out:
# 0.6949152542372882

# %%
auc_roc_RF = roc_auc_score(y_test, pred_RF)
auc_roc_RF
# Out:
# 0.7662337662337662

# %%
conf_matrix_RF = confusion_matrix(y_test, pred_RF)
conf_matrix_RF
# Out:
# array([[17425,     0],
#        [   36,    41]])

# %%
print(f'Random Forest Confusion Matrix without sampling')
fig, axes = plt.subplots(figsize=(6,5))
sns.heatmap(conf_matrix_RF, annot=True, axes=axes, cmap='Blues', fmt='d')
# Out:
# Random Forest Confusion Matrix without sampling
# <Axes: >

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, pred_RF))
print(f'Random Forest Classifier Confusion matrix without sampling')
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     17425
#          1.0       1.00      0.53      0.69        77
#
#     accuracy                           1.00     17502
#    macro avg       1.00      0.77      0.85     17502
# weighted avg       1.00      1.00      1.00     17502
#
# Random Forest Classifier Confusion matrix without sampling

# %%
from sklearn.metrics import roc_curve, auc

y_true = y_test
y_scores = pred_RF

fpr, tpr, thresholds = roc_curve(y_true, y_scores)

roc_auc = auc(fpr, tpr)
print(f'AUC-ROC Curve - Without Sampling')
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = {roc_auc:.2f})')
plt.plot([0,1],[0,1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# AUC-ROC Curve - Without Sampling

# %% [markdown]
# **5. Data Training and Processing - Using SMOTE Sampling method**

# %%
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from collections import Counter

# %%
scaler = StandardScaler()
x_train_scale = scaler.fit_transform(x_train)
x_test_scale = scaler.transform(x_test)

# %%
smote = SMOTE(random_state=42)
x_train_resample, y_train_resample = smote.fit_resample(x_train_scale, y_train)

# %%
print("Resampled class distribution:", Counter(y_train_resample))
# Out:
# Resampled class distribution: Counter({0.0: 40683, 1.0: 40683})

# %%
#Random Forest
from sklearn.ensemble import RandomForestClassifier
RF1=RandomForestClassifier(random_state=42)

# %%
RF1.fit(x_train_resample,y_train_resample)
# Out:
# RandomForestClassifier(random_state=42)

# %%
pred_RF1 = RF1.predict(x_test_scale)

# %% [markdown]
# **Evaluation Metrics - After SMOTE Sampling**

# %%
accRF1 = accuracy_score(y_test, pred_RF1)
accRF1
# Out:
# 0.9982287738544167

# %%
precRF1 = precision_score(y_test, pred_RF1)
precRF1
# Out:
# 0.896551724137931

# %%
recall_RF1 = recall_score(y_test, pred_RF)
recall_RF1
# Out:
# 0.5324675324675324

# %%
F1_RF1 = f1_score(y_test, pred_RF)
F1_RF1
# Out:
# 0.6949152542372882

# %%
auc_roc_RF1 = roc_auc_score(y_test, pred_RF)
auc_roc_RF1
# Out:
# 0.7662337662337662

# %%
conf_matrix_RF1 = confusion_matrix(y_test, pred_RF)
conf_matrix_RF1
# Out:
# array([[17425,     0],
#        [   36,    41]])

# %%
print(f'Random Forest Confusion Matrix using SMOTE sampling')
fig, axes = plt.subplots(figsize=(6,5))
sns.heatmap(conf_matrix_RF1, annot=True, axes=axes, cmap='Blues', fmt='d')
# Out:
# Random Forest Confusion Matrix using SMOTE sampling
# <Axes: >

# %%
from sklearn.metrics import roc_curve, auc

y_true = y_test
y_scores = pred_RF1

fpr, tpr, thresholds = roc_curve(y_true, y_scores)

roc_auc = auc(fpr, tpr)

print(f'AUC-ROC Curve - After SMOTE Sampling')
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0,1],[0,1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# AUC-ROC Curve - After SMOTE Sampling
